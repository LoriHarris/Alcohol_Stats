# %%
import pandas as pd
url = "http://www.iard.org/resources/minimum-legal-age-limits/"

# %%
tables = pd.read_html(url)
tables
# Out:
# [          Country/Territory                                On-premise  \
#  0               Afghanistan                  [all sale is prohibited]
#  1                   Albania                                        18
#  2                   Algeria                                        18
#  3                   Andorra                                        18
#  4       Antigua and Barbuda                                        16
#  5                 Argentina                                        18
#  6                   Armenia                                        18
#  7                 Australia                                       18*
#  8                   Austria  [varies by jurisdiction and by beverage]
#  9                Azerbaijan                                        18
#  10                  Bahamas                                        18
#  11                  Bahrain                  [all sale is prohibited]
# ...

# %%
df = tables[0]
df.head()
# Out:
#      Country/Territory                On-premise               Off-premise  \
# 0          Afghanistan  [all sale is prohibited]  [all sale is prohibited]
# 1              Albania                        18                        18
# 2              Algeria                        18                        18
# 3              Andorra                        18                        18
# 4  Antigua and Barbuda                        16                    [none]
#
#   Notes                                        Legislation
# 0   NaN  Law to Fight Against Alcoholic Beverages and N...
# 1   NaN  Law 9518 of 18 April 2006 For the protection o...
# 2   NaN                     Order No. 26-75 of 1975 Art 14
# 3   NaN  Decree 16-6-2004 Approving Regulation of Sale ...
# 4   NaN         Licensing (intoxicating liquor) Act Ch 249

# %%
df.to_csv('minimum_age.csv')
