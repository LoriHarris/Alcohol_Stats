# %%
import pandas as pd

# %%
alcohol_use_2013 = pd.read_csv("NSDUHsaeTotalsCSVs2013/NSDUHsaeCountTab09-2013.csv", header = 4, index_col=1)

alcohol_use_2013.drop(["Order", "12 or Older 95% CI (Lower)", "12 or Older 95% CI (Upper)", "12-17 95% CI (Lower)", "12-17 95% CI (Upper)", "18-25 95% CI (Lower)", "18-25 95% CI (Upper)", "26 or Older 95% CI (Lower)", "26 or Older 95% CI (Upper)", "18 or Older 95% CI (Lower)", "18 or Older 95% CI (Upper)"] , axis= 1, inplace=True)

alcohol_use_2013.rename(columns={"12 or Older Estimate": "Total # Polled", "12-17 Estimate": "Ages 12-17", "18-25 Estimate": "Ages 18-25", "26 or Older Estimate": "Ages 26+", "18 or Older Estimate":"Ages 18+"}, inplace=True)

alcohol_use_2013["Year"] = '2013'

alcohol_use_2013.head()

#alcohol_use_2013.to_csv("Alcohol_Use_2013.csv")
# Out:
#            Total # Polled Ages 12-17 Ages 18-25 Ages 26+ Ages 18+  year
# State
# Total U.S.        136,188      3,047     20,783  112,358  133,141  2013
# Northeast          27,304        586      3,973   22,744   26,718  2013
# Midwest            30,964        673      4,710   25,581   30,291  2013
# South              46,833      1,087      7,277   38,470   45,747  2013
# West               31,087        701      4,823   25,563   30,386  2013

# %%
alcohol_use_2014 = pd.read_csv("NSDUHsaeTotalsCSVs2014/NSDUHsaeTotalsTab09-2014.csv", header = 4, index_col=1)

alcohol_use_2014.drop(["Order", "12 or Older 95% CI (Lower)", "12 or Older 95% CI (Upper)", "12-17 95% CI (Lower)", "12-17 95% CI (Upper)", "18-25 95% CI (Lower)", "18-25 95% CI (Upper)", "26 or Older 95% CI (Lower)", "26 or Older 95% CI (Upper)", "18 or Older 95% CI (Lower)", "18 or Older 95% CI (Upper)"] , axis= 1, inplace=True)

alcohol_use_2014.rename(columns={"12 or Older Estimate": "Total # Polled", "12-17 Estimate": "Ages 12-17", "18-25 Estimate": "Ages 18-25", "26 or Older Estimate": "Ages 26+", "18 or Older Estimate":"Ages 18+"}, inplace=True)

alcohol_use_2014["Year"] = '2014'

alcohol_use_2014.head()

#alcohol_use_2014.to_csv("Alcohol_Use_2014.csv")
# Out:
#            Total # Polled Ages 12-17 Ages 18-25 Ages 26+ Ages 18+  year
# State
# Total U.S.        138,279      2,875     20,777  114,627  135,404  2014
# Northeast          27,463        550      3,923   22,991   26,913  2014
# Midwest            31,066        609      4,681   25,776   30,457  2014
# South              47,855      1,020      7,320   39,515   46,835  2014
# West               31,894        696      4,853   26,345   31,198  2014

# %%
alcohol_use_2015 = pd.read_csv("NSDUHsaeTotalsCSVs-2015/NSDUHsaeTotals-Tab06-2015.csv", header = 5, index_col=1)

alcohol_use_2015.drop(["Order", "12 or Older 95% CI (Lower)", "12 or Older 95% CI (Upper)", "12-17 95% CI (Lower)", "12-17 95% CI (Upper)", "18-25 95% CI (Lower)", "18-25 95% CI (Upper)", "26 or Older 95% CI (Lower)", "26 or Older 95% CI (Upper)", "18 or Older 95% CI (Lower)", "18 or Older 95% CI (Upper)"] , axis= 1, inplace=True)

alcohol_use_2015.rename(columns={"12 or Older Estimate": "Total # Polled", "12-17 Estimate": "Ages 12-17", "18-25 Estimate": "Ages 18-25", "26 or Older Estimate": "Ages 26+", "18 or Older Estimate":"Ages 18+"}, inplace=True)

alcohol_use_2015["Year"] = '2015'

alcohol_use_2015.head()

#alcohol_use_2015.to_csv("Alcohol_Use_2015.csv")
# Out:
#            Total # Polled Ages 12-17 Ages 18-25 Ages 26+ Ages 18+  year
# State
# Total U.S.        139,003      2,632     20,591  115,780  136,371  2015
# Northeast          27,037        520      3,936   22,581   26,517  2015
# Midwest            30,747        552      4,592   25,602   30,194  2015
# South              48,617        920      7,273   40,424   47,697  2015
# West               32,602        639      4,789   27,174   31,963  2015

# %%
alcohol_use_2016 = pd.read_csv("NSDUHsaeTotals2016-CSVs/NSDUHsaeTotals-Tab12-2016.csv", header = 5, index_col=1)

alcohol_use_2016.drop(["Order", "12 or Older 95% CI (Lower)", "12 or Older 95% CI (Upper)", "12-17 95% CI (Lower)", "12-17 95% CI (Upper)", "18-25 95% CI (Lower)", "18-25 95% CI (Upper)", "26 or Older 95% CI (Lower)", "26 or Older 95% CI (Upper)", "18 or Older 95% CI (Lower)", "18 or Older 95% CI (Upper)"] , axis= 1, inplace=True)

alcohol_use_2016.rename(columns={"12 or Older Estimate": "Total # Polled", "12-17 Estimate": "Ages 12-17", "18-25 Estimate": "Ages 18-25", "26 or Older Estimate": "Ages 26+", "18 or Older Estimate":"Ages 18+"}, inplace=True)

alcohol_use_2016["Year"] = '2016'

alcohol_use_2016.head()

#alcohol_use_2016.to_csv("Alcohol_Use_2016.csv")
# Out:
#            Total # Polled Ages 12-17 Ages 18-25 Ages 26+ Ages 18+  year
# State
# Total U.S.        137,531      2,341     20,060  115,130  135,190  2016
# Northeast          26,782        450      3,890   22,442   26,332  2016
# Midwest            30,827        524      4,553   25,749   30,302  2016
# South              47,824        828      7,035   39,960   46,996  2016
# West               32,098        538      4,582   26,978   31,560  2016

# %%
alcohol_use_2017 = pd.read_csv("NSDUHsaeTotals2017-CSVs/NSDUHsaeTotals-Tab13-2017.csv", header = 5, index_col=1)

alcohol_use_2017.drop(["Order", "12 or Older 95% CI (Lower)", "12 or Older 95% CI (Upper)", "12-17 95% CI (Lower)", "12-17 95% CI (Upper)", "18-25 95% CI (Lower)", "18-25 95% CI (Upper)", "26 or Older 95% CI (Lower)", "26 or Older 95% CI (Upper)", "18 or Older 95% CI (Lower)", "18 or Older 95% CI (Upper)"] , axis= 1, inplace=True)

alcohol_use_2017.rename(columns={"12 or Older Estimate": "Total # Polled", "12-17 Estimate": "Ages 12-17", "18-25 Estimate": "Ages 18-25", "26 or Older Estimate": "Ages 26+", "18 or Older Estimate":"Ages 18+"}, inplace=True)

alcohol_use_2017["Year"] = '2017'

alcohol_use_2017.head()

#alcohol_use_2017.to_csv("Alcohol_Use_2017.csv")
# Out:
#            Total # Polled Ages 12-17 Ages 18-25 Ages 26+ Ages 18+  year
# State
# Total U.S.        138,664      2,377     19,542  116,745  136,287  2017
# Northeast          27,062        434      3,810   22,817   26,628  2017
# Midwest            30,919        536      4,463   25,920   30,383  2017
# South              48,026        865      6,768   40,392   47,160  2017
# West               32,657        541      4,501   27,615   32,116  2017

# %%
complete_US_stats = pd.concat([alcohol_use_2017, alcohol_use_2016, alcohol_use_2015, alcohol_use_2014, alcohol_use_2013], axis=0)

# %%
complete_US_stats.head(200)
# Out:
#                      Total # Polled Ages 12-17 Ages 18-25 Ages 26+ Ages 18+  \
# State
# Total U.S.                  138,664      2,377     19,542  116,745  136,287
# Northeast                    27,062        434      3,810   22,817   26,628
# Midwest                      30,919        536      4,463   25,920   30,383
# South                        48,026        865      6,768   40,392   47,160
# West                         32,657        541      4,501   27,615   32,116
# Alabama                       1,709         33        259    1,417    1,675
# Alaska                          302          6         42      254      296
# Arizona                       2,917         46        393    2,478    2,872
# Arkansas                        987         21        152      814      966
# California                   16,575        272      2,320   13,984   16,303
# Colorado                      2,764         42        371    2,351    2,722
# ...

# %%
state_groups= complete_US_stats.groupby(['State', 'Year']).max()

# %%
state_groups.dtypes
# Out:
# Total # Polled    object
# Ages 12-17        object
# Ages 18-25        object
# Ages 26+          object
# Ages 18+          object
# dtype: object

# %%
state_groups.to_csv("State_stats.csv")
